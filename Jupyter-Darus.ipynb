# %%
import poreana as pa
import porems as pms
import matplotlib.pyplot as plt
import numpy as np
import gro_exp as u
import pandas as pd
import seaborn as sns
from collections import OrderedDict

# %% [markdown]
# # Set System
# Load a Obj-File createt with a the PoreAna package. A example how it works you can find in the jupyter-notebook sim_ana.ipynb

# %%
system = "diff_BEN_mc_cos.obj"

# %% [markdown]
# # Density

# %% [markdown]
# # Diffusion

# %%
# Out:
# /Users/Marc/opt/anaconda3/envs/pore/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Marc/opt/anaconda3/envs/pore/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Overview

# %%
data = {"Box": box , "Reservoir": pore_res,"$D^{MC}_{NVT}$": [nvt for nvt in diff_nvt.values()],"$D^{MC}_{NVT,SD}$": [nvt for nvt in diff_nvt_sd.values()], "$D^{MSD}_{NVT,Z}$": [nvt for nvt in diff_nvt_z.values()],"$D^{MC}_{NVT,Z}$": [nvt for nvt in diff_nvt_z_mc.values()], "$D_{Res}^{MC} (SD)$": diff_res, "$D_{Res}^{MC} (MD)$": diff_res_md, "$D_{Res}^{MC}/D_{NVT,Z}$": res_ratio, "$D_{Res}^{MC}$": diff_res, "$\\frac{D_{Res}}{D_{Pore}}$": [diff_res[i]/diff_pore[i] for i in range(len(strings.keys()))],"$\\frac{D_{Res}}{D_{Pore}} (MD)$": [diff_res_md[i]/diff_pore_md[i] for i in range(len(strings.keys()))],"$D_{Pore}^{MC}$": diff_pore,"$D_{Pore}^{MC} (MD)$": diff_pore_md,"$D_{Pore}^{Bin}$": diff_pore_bin,"$D_{Pore}^{Bin,MD}$": diff_pore_bin_md }

df = pd.DataFrame(data, index = strings.keys())


display(df)
# Out:
#                              Box  Reservoir  $D^{MC}_{NVT}$  \
# 295_pore_1OL  [7.08, 7.02, 30.7]         10            1.99
# 295_pore_2OL  [7.08, 7.02, 30.7]         10            0.69
# 295_pore_3OL  [7.08, 7.02, 30.7]         10            0.39
# 295_pore_4OL  [7.08, 7.02, 30.7]         10            0.24
# 295_pore_BEN  [7.08, 7.02, 30.7]         10            2.27
# 295_pore_TOL  [7.08, 7.02, 30.7]         10            2.06
# 295_pore_PYN  [7.08, 7.02, 30.7]         10            1.20
# 295_pore_PYR  [7.08, 7.02, 30.7]         10            0.78
# 295_pore_C5N  [7.08, 7.02, 30.7]         10            3.13
# 295_pore_C6N  [7.08, 7.02, 30.7]         10            1.42
# 295_pore_6AN  [7.08, 7.02, 30.7]         10            3.70
# 295_pore_7AN  [7.08, 7.02, 30.7]         10            2.79
# 295_pore_SOL  [7.08, 7.02, 30.7]         10            2.17
# 295_pore_THF  [7.08, 7.02, 30.7]         10            1.59
#
# ...

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 8
BIGGER_SIZE = 8

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.figure(figsize=(30,10))
plt.subplot(2,3, 1)

marker = ["*","^","D","x"]
color= sns.color_palette("deep")
mols = {}
mols[0] = ["1OL","2OL","3OL","4OL"]
mols[1] = ["BEN","TOL","PYR","PYN"]
mols[2] = ["C5N","C6N","6AN","7AN",]
mols[3] = ["SOL","THF"]
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):
        plt.scatter(x=diff_res[i+4*z],y=diff_res_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([0,4])
plt.ylim([0,4])
plt.xlabel("MD")
plt.ylabel("SD")
plt.subplot(2,3, 2)
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):
        plt.scatter(x=diff_pore[i+4*z],y=diff_pore_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([0,2.5])
plt.ylim([0,2.5])
plt.legend()
plt.title("Pore")
plt.xlabel("MD")
plt.ylabel("SD")
plt.subplot(2,3, 3)
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):
        plt.scatter(x=diff_res[i+4*z]/diff_pore[i+4*z],y=diff_res_md[i+4*z]/diff_pore_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([1,3.5])
plt.ylim([1,3.5])
plt.legend()
plt.title("Ratio")
plt.xlabel("MD")

plt.ylabel("SD")

plt.subplot(2,3, 4)
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):
        plt.scatter(x=diff_res_h[i+4*z],y=diff_res_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([0,4])
plt.ylim([0,4])
plt.legend()
plt.title("Reservoir")
plt.xlabel("MD (H)")
plt.ylabel("MD")
plt.subplot(2,3, 5)
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):
        plt.scatter(x=diff_pore_h[i+4*z],y=diff_pore_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([0,2.5])
plt.ylim([0,2.5])
plt.legend()
plt.title("Pore")
plt.xlabel("MD (H)")
plt.ylabel("MD")
plt.subplot(2,3, 6)
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):
        plt.scatter(x=diff_res_h[i+4*z]/diff_pore_h[i+4*z],y=diff_res_md[i+4*z]/diff_pore_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([1,3.5])
plt.ylim([1,3.5])
plt.legend()
plt.title("Ratio")
plt.xlabel("MD (H)")
plt.ylabel("MD")
# Out:
# Text(0, 0.5, 'MD')

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 8
BIGGER_SIZE = 8

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.figure(figsize=(30,15))
plt.subplot(2,2, 1)

marker = ["*","^","D","x"]
color= sns.color_palette("deep")
mols = {}
mols[0] = ["1OL","2OL","3OL","4OL"]
mols[1] = ["BEN","TOL","PYR","PYN"]
mols[2] = ["C5N","C6N","6AN","7AN",]
mols[3] = ["SOL","THF"]
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):

        plt.scatter(x=diff_nvt_z_mc[mol],y=diff_res_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([0,4])
plt.ylim([0,4])
plt.legend()
plt.xlabel("NVT Z (MC)")
plt.ylabel("Reservoir")


plt.subplot(2,2, 2)
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):

        plt.scatter(x=diff_nvt_z[mol],y=diff_res_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([0,4])
plt.ylim([0,4])
plt.legend()
plt.xlabel("NVT Z (MSD)")
plt.ylabel("Reservoir")


plt.subplot(2,2, 3)
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):

        plt.scatter(x=diff_nvt[mol],y=diff_res_md[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
plt.plot([0,10],[0,10])
plt.xlim([0,4])
plt.ylim([0,4])
plt.legend()
plt.xlabel("NVT (MC)")
plt.ylabel("Reservoir")

plt.subplot(2,2, 4)
mol_vec = []
i_vec = []
for mol_i,z in zip(mols,range(len(mols))):
    for mol,i in zip(mols[mol_i], range(len(diff_res))):
        plt.scatter(x=i+4*z,y=res_ratio[i+4*z], marker=marker[mol_i], color = color[i], label=mol, s=100 )
        i_vec.append(i+4*z)
        mol_vec.append(mol)
mean = np.mean(res_ratio)
std = np.std(res_ratio)
sns.lineplot(np.linspace(0,25,100),[mean for i in range(100)],label = "Average$)")
plt.axhspan(mean-std, mean+std, facecolor='grey', alpha=0.3,  label ="STD$)" )
plt.xticks(i_vec,mol_vec)
plt.plot(np.linspace(0,14,10),[1 for i in range(10)])
plt.xlim([0,14])
plt.ylim([0.9,1.2])
plt.legend()
plt.xlabel("NVT (MC)")
plt.ylabel("Reservoir")
# Out:
# /Users/Marc/opt/anaconda3/envs/pore/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Reservoir')

# %%
data = {"Box": box , "Reservoir": pore_res, "$\\frac{D_{Res}}{D_{Pore}}$": [diff_res[i]/diff_pore[i] for i in range(len(strings.keys()))],"Density (H)": density_h,"Density": density,"Target Density": target_vec ,"Target Density (H)": target_vec_h ,"Percent deviation  (%)": [((target_vec[i]-density[i])/density_h[i] * 100) for i in range(len(density))], "Percent deviation (H)(%)": [((target_vec[i]-density_h[i])/density[i] * 100) for i in range(len(density))],"$D^{MC}_{NVT}$": [nvt for nvt in diff_nvt.values()],"$D^{MC}_{NVT,SD}$": [nvt for nvt in diff_nvt_sd.values()], "$D_{Res}^{MC}$": diff_res,  "$\\frac{D_{Res}}{D_{NVT}}$": [diff_res[i]/nvt for i,nvt in zip(range(len(strings.keys())),diff_nvt.values())],"$\\frac{D_{Res}}{D_{NVT,SD}}$": [diff_res[i]/nvt for i,nvt in zip(range(len(strings.keys())),diff_nvt_sd.values())],"$D_{Pore}^{MC}$": diff_pore,"$D_{Pore}^{Bin}$": diff_pore_bin,"$D_{Pore}^{Bin,H}$": diff_pore_bin_h }

df = pd.DataFrame(data, index = strings.keys())


display(df)
# Out:
#                              Box  Reservoir  $\frac{D_{Res}}{D_{Pore}}$  \
# 295_pore_1OL  [7.08, 7.02, 30.7]         10                    2.632065
# 295_pore_2OL  [7.08, 7.02, 30.7]         10                    2.795791
# 295_pore_3OL  [7.08, 7.02, 30.7]         10                    2.836626
# 295_pore_4OL  [7.08, 7.02, 30.7]         10                    2.901200
# 295_pore_BEN  [7.08, 7.02, 30.7]         10                    2.482921
# 295_pore_TOL  [7.08, 7.02, 30.7]         10                    2.535136
# 295_pore_PYN  [7.08, 7.02, 30.7]         10                    3.377098
# 295_pore_PYR  [7.08, 7.02, 30.7]         10                    3.081558
# 295_pore_C5N  [7.08, 7.02, 30.7]         10                    1.836843
# 295_pore_C6N  [7.08, 7.02, 30.7]         10                    2.056231
# 295_pore_6AN  [7.08, 7.02, 30.7]         10                    1.798152
# 295_pore_7AN  [7.08, 7.02, 30.7]         10                    1.901261
# ...

# %%
plt.figure(figsize=(30,8))
diff_res = []
diff_pore = []
diff_res_h = []
diff_pore_h = []
diff_pore_bin = []
diff_pore_bin_h = []


reservoirs = [0,1.5]
pores = [10.7,19.3]




for sys,i in zip(strings.keys(), range(len(strings.keys()))):

        
    # Save results 
    diff_res.append(pa.diffusion.mc_fit(strings[sys]["mc"], is_plot=False, section = reservoirs,is_print=False, len_step = [10,20,30,40,50,60])[0])
    diff_pore.append(pa.diffusion.mc_fit(strings[sys]["mc"], is_plot=False, section = pores,is_print=False, len_step = [10,20,30,40,50,60])[0])
    diff_res_h.append(pa.diffusion.mc_fit(strings[sys]["mc_h"], is_plot=False, section = reservoirs,is_print=False, len_step = [10,20,30,40,50,60])[0])
    diff_pore_h.append(pa.diffusion.mc_fit(strings[sys]["mc_h"], is_plot=False, section = pores,is_print=False, len_step = [10,20,30,40,50,60])[0])
    
   #diff_pore_bin.append()

    diff_pore_bin.append(pa.diffusion.mean(pa.diffusion.bins(strings[sys]["bin"]), pa.density.bins(strings[sys]["dens"],is_print=False),is_print=False))
    diff_pore_bin_h.append(pa.diffusion.mean(pa.diffusion.bins(strings[sys]["bin_h"]), pa.density.bins(strings[sys]["dens"],is_print=False),is_print=False))

# %%
data = {"Box": box , "Reservoir": pore_res, "$D^{MC}_{NVT}$": [nvt for nvt in diff_nvt.values()],"$D^{MC}_{NVT,SD}$": [nvt for nvt in diff_nvt_sd.values()], "$D_{Res}^{MC}$": diff_res,"$D_{Res}^{MC} (H)$": diff_res_h,"Percent deviation (Res) (%)": [((diff_res_h[i]-diff_res[i])/diff_res_h[i] * 100) for i in range(len(diff_res))], "$D_{Pore}^{MC}$": diff_pore, "$D_{Pore}^{MC} (H)$": diff_pore_h,"Percent deviation (Pore) (%)": [((diff_pore_h[i]-diff_pore[i])/diff_pore_h[i] * 100) for i in range(len(diff_res))], "$D_{Pore}^{Bin}$": diff_pore_bin,"$D_{Pore}^{Bin,H}$": diff_pore_bin_h,"Percent deviation (Pore Bin) (%)": [((diff_pore_bin_h[i]-diff_pore_bin[i])/diff_pore_bin_h[i] * 100) for i in range(len(diff_res))] }

df = pd.DataFrame(data, index = strings.keys())

display(df)
# Out:
#                              Box  Reservoir  $D^{MC}_{NVT}$  \
# 295_pore_1OL  [7.08, 7.02, 30.7]         10            1.99
# 295_pore_2OL  [7.08, 7.02, 30.7]         10            0.69
# 295_pore_3OL  [7.08, 7.02, 30.7]         10            0.39
# 295_pore_4OL  [7.08, 7.02, 30.7]         10            0.24
# 295_pore_BEN  [7.08, 7.02, 30.7]         10            2.27
# 295_pore_TOL  [7.08, 7.02, 30.7]         10            2.06
# 295_pore_PYN  [7.08, 7.02, 30.7]         10            1.20
# 295_pore_PYR  [7.08, 7.02, 30.7]         10            0.78
# 295_pore_C5N  [7.08, 7.02, 30.7]         10            3.13
# 295_pore_C6N  [7.08, 7.02, 30.7]         10            1.42
# 295_pore_6AN  [7.08, 7.02, 30.7]         10            3.70
# 295_pore_7AN  [7.08, 7.02, 30.7]         10            2.79
# 295_pore_SOL  [7.08, 7.02, 30.7]         10            2.17
# 295_pore_THF  [7.08, 7.02, 30.7]         10            1.59
#
# ...

# %%
density_res = []
density_res_h = []
density_pore = []
density_pore_h = []
density_pore_mean = []
density_pore_h_mean = []
for sys,i in zip(strings.keys(), range(len(strings.keys()))):
    dens = pa.density.bins(strings[sys]["dens"], target_dens = target_density[sys[-3:]], is_print=False)
    density_res.append(pa.density.bins(strings[sys]["dens"],is_print=False)["dens"]["ex"])
    density_pore.append(pa.density.bins(strings[sys]["dens"],is_print=False)["dens"]["in"])
    density_pore_mean.append(pa.density.mean(dens)["dens"])
    
    dens = pa.density.bins(strings[sys]["dens_h"], target_dens = target_density[sys[-3:]], is_print=False)
    density_res_h.append(pa.density.bins(strings[sys]["dens_h"],is_print=False)["dens"]["ex"])
    density_pore_h.append(pa.density.bins(strings[sys]["dens_h"],is_print=False, area = [[10,90],[10,90]])["dens"]["in"])
    density_pore_h_mean.append(pa.density.mean(dens)["dens"])
    
data = {"Box": box , "Reservoir": density_res, "Reservoir (H)": density_res_h, "Pore":  density_pore,"Pore Mean":  density_pore_mean, "Pore (H)":  density_pore_h,"Pore Mean (H)":  density_pore_h_mean, "rho_p/rho_b": [density_res[i]/density_pore_mean[i] for i in range(len(density_pore))], "rho_p/rho_b (H)": [density_res_h[i]/density_pore_h_mean[i] for i in range(len(density_pore))] } 

df = pd.DataFrame(data, index = strings.keys())

display(df)
# Out:
# Mean Density: 13.302 #/nm^3; 707.767 kg/m^3
# Mean Density: 12.267 #/nm^3; 652.721 kg/m^3
# Mean Density: 9.168 #/nm^3; 701.385 kg/m^3
# Mean Density: 8.759 #/nm^3; 670.052 kg/m^3
# Mean Density: 6.996 #/nm^3; 698.119 kg/m^3
# Mean Density: 6.922 #/nm^3; 690.794 kg/m^3
# Mean Density: 5.925 #/nm^3; 729.233 kg/m^3
# Mean Density: 5.839 #/nm^3; 718.727 kg/m^3
# Mean Density: 5.779 #/nm^3; 749.578 kg/m^3
# Mean Density: 6.023 #/nm^3; 781.280 kg/m^3
# Mean Density: 4.842 #/nm^3; 740.764 kg/m^3
# Mean Density: 5.131 #/nm^3; 785.003 kg/m^3
# Mean Density: 6.680 #/nm^3; 877.461 kg/m^3
# Mean Density: 6.754 #/nm^3; 887.081 kg/m^3
# Mean Density: 7.896 #/nm^3; 879.621 kg/m^3
# Mean Density: 7.730 #/nm^3; 861.138 kg/m^3
# Mean Density: 5.285 #/nm^3; 615.547 kg/m^3
# Mean Density: 5.710 #/nm^3; 665.006 kg/m^3
# Mean Density: 4.665 #/nm^3; 651.882 kg/m^3
# Mean Density: 5.092 #/nm^3; 711.568 kg/m^3
# Mean Density: 3.862 #/nm^3; 552.648 kg/m^3
# Mean Density: 4.276 #/nm^3; 611.904 kg/m^3
# ...

# %%
color= sns.color_palette("deep")
mols = {}
mols[0] = ["1OL","2OL","3OL","4OL"]
mols[1] = ["BEN","TOL","PYR","PYN"]
mols[2] = ["C5N","C6N","6AN","7AN",]
mols[3] = ["SOL","THF"]

for sys,i in zip(strings.keys(), range(8)):
    diff = pa.diffusion.bins(strings[sys]["bin"])
    
    plt.ylim([0,2.5])
    plt.xlim([0,2.5])
    sns.lineplot(np.linspace(0,box[sys][2],100),[diff_nvt_z[sys[-3:]] for i in range(100)], label = sys[-3:],color = color[i])
    pa.diffusion.bins_plot(diff, kwargs={"label": None, "color": color[i]})
    #dens = pa.density.bins(strings[sys]["dens"])
    #pa.density.bins_plot(dens)
print(diff)
# Out:
# /Users/Marc/opt/anaconda3/envs/pore/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Marc/opt/anaconda3/envs/pore/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
color= sns.color_palette("deep")
mols = {}
mols[0] = ["1OL","2OL","3OL","4OL"]
mols[1] = ["BEN","TOL","PYR","PYN"]
mols[2] = ["C5N","C6N","6AN","7AN",]
mols[3] = ["SOL","THF"]




dens = pa.density.bins("sim/dens_paper/7AN/ana/dens_7AN.obj")
pa.density.bins_plot(dens)
pa.density.mean(dens)
# Out:
# Density inside  Pore = 4.140 #/nm^3 ; 688.902 kg/m^3
# Density outside Pore = 4.117 #/nm^3 ; 684.989 kg/m^3
# Mean Density: 3.795 #/nm^3; 631.427 kg/m^3
# {'num_dens': 3.7948154834959067, 'dens': 631.4271748695094}
